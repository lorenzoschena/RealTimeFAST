# %% [markdown]
# # Zmq Live PUB-SUB

# %%
from real_fast_interactor import RFInteractor

# %%
rfi = RFInteractor(ZmqInAddress=None, ZmqOutAddress='tcp://127.0.0.1:5556', verbose=False)
# Out:
# ZMQ Real Time interactor for FAST initialized.
#  PUB-SUB protocol: tcp://127.0.0.1:5556 | REQ-REP protocol: None

# %%
rfi.fast_sub(25)
# Out:
# <div>                            <div id="2f6d1390-709c-4fe8-8624-55843117dfef" class="plotly-graph-div" style="height:1200px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f6d1390-709c-4fe8-8624-55843117dfef")) {                    Plotly.newPlot(                        "2f6d1390-709c-4fe8-8624-55843117dfef",                        [{"mode":"lines","name":" Wind1VelX","y":[10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10
# ...

# %%
tmp = rfi.subscriber.recv_json()

# %%
rfi.sub_dict

# %%
tmp

# %%
for key, value in tmp.items():
    if key not in rfi.sub_dict:
        rfi.sub_dict[key] = []  
        rfi.sub_dict[key].append(value)

# %%
rfi.sub_dict
